# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('data/이낙연_분석.csv')
df1 = df1.iloc[:10000,:]
df1 = df1.rename(columns={"post": "sentence"})
df1
# Out:
#                                               sentence like_count  \
# 0    <홍영표 김종민 신동근 의원님 지지선언, 힘이 솟습니다>\n더불어민주당 홍영표, 김...        636
# 1    <윤석열씨의 대책없는 노동관>\n“손발로 하는 노동은 인도도 안 하고 아프리카나 한...        633
# 2    <광주시민께 드리는 글 - 민주당이 승리하도록,  결선투표를 만들어주십시오>\n존경...       1.3K
# 3    <정치인의 망발을 언제까지 견뎌야 합니까>\n어제 국회 본회의 대정부질문에서 국민의...       1.7K
# 4    <역사의 순간, 역사적인 선택에 참여해주십시오>\n더불어민주당의 대선후보를 선출하는...       1.1K
# ..                                                 ...        ...
# 609  8월 7~8일 큰 수해를 당한 전북 남원, 전남 곡성 구례, 경남 하동 화개장터. ...         2K
# 610  서울 종로구 통인시장. 국내외 관광객과 손님들로 붐비던 곳. 코로나19로 한산해졌습...       2.8K
# 611  저희 더불어민주당 소속 오영환 국회의원의 미담이 한 달 만에 세상에 알려졌습니다.\...       3.7K
# 612  국내 제약기업 셀트리온이 코로나19 항체치료제 9만명분 생산체제를 갖춘다고 합니다....       2.2K
# 613  코로나19로 많은 국민께서 고통 받고 계십니다. 어제 14일 중소기업중앙회(회장 김...       1.7K
#
#     comment_count  share_count                 date  \
# 0             224          224  2021-09-16 00:00:00
# 1             413          264  2021-09-16 00:00:00
# 2             817          450  2021-09-16 00:00:00
# 3             534          482  2021-09-15 00:00:00
# 4             408          330  2021-09-14 00:00:00
# ..            ...          ...                  ...
# 609           145          132  2020-09-19 00:00:00
# 610           210          116  2020-09-18 00:00:00
# 611           177          163  2020-09-17 00:00:00
# 612           188          114  2020-09-17 00:00:00
# 613           265          124  2020-09-15 00:00:00
#
#                                                comment         score  ratio  \
# 0    ['홍영표', '김종민', '신동근', '의원님', '지지', '선언', '힘', ...  1.000000e+01   3.00
# 1    ['윤석열', '씨', '의', '대책', '없는', '노동', '관', '손발',...  8.000000e+00   2.29
# 2    ['광주', '시민', '께', '드리는', '글', '민주당', '이', '승리'...  7.666667e+00   1.94
# 3    ['정치인', '의', '망발', '을', '언제', '까지', '견뎌야', '합'... -1.110223e-16  -0.00
# 4    ['역사', '의', '순간', '역사', '적', '인', '선택', '에', '...  5.000000e+00   1.47
# ..                                                 ...           ...    ...
# 609  ['8월', '78일', '큰', '수해', '를', '당한', '전북', '남원'... -4.943358e+00  -1.88
# 610  ['서울', '종로구', '통인시장', '국내외', '관광객', '과', '손님',...  5.048487e-01   0.21
# 611  ['저희', '더불어', '민주당', '소속', '오영환', '국회의원', '의',...  1.091078e+00   0.41
# 612  ['국내', '제약기업', '셀트리온', '이', '코로나', '19', '항체',... -3.330669e-16  -0.00
# 613  ['코로나', '19', '로', '많은', '국민', '께서', '고통', '받고... -3.723308e+00  -1.42
#
#       백신  부동산  ... 국민지원금    청년   문재인   윤석열  이준석  이재명    복지   접종   노조    기업
# 0    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN  True  NaN  NaN   NaN
# 1    NaN  NaN  ...   NaN  True   NaN  True  NaN  NaN   NaN  NaN  NaN   NaN
# 2    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN  True  NaN  NaN   NaN
# 3    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 4    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# ..   ...  ...  ...   ...   ...   ...   ...  ...  ...   ...  ...  ...   ...
# 609  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 610  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 611  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 612  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  True
# 613  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  True
#
# [614 rows x 22 columns]

# %%
df2 = pd.read_csv('data/이재명_분석.csv')
df2 = df2.iloc[:10000,:]
df2 = df2.rename(columns={"post": "sentence"})
df2
# Out:
#                                               sentence like_count  \
# 0    <'임금체불 근절' 노동자의 시름을 덜어드리겠습니다>\n민족의 대명절인 한가위가 며...       1.3K
# 1    <세계 7번째 SLBM 성공, 자주국방 실현에 성큼 다가선 쾌거>\n오늘 우리 해군...         2K
# 2    - 제3차 경기도 재난기본소득 지급 관련 경기도지사 기자회견 - \n<10월 1일,...       2.6K
# 3    <기본소득의 수혜자가 ‘전 국민’인 이유, 추가답변 드립니다>\n어제 이낙연 후보님...       5.1K
# 4    <벼랑 끝에 선 심정을 헤아려야 합니다.>\n안타까운 소식들이 연이어 들려옵니다. ...       1.5K
# ..                                                 ...        ...
# 704  <공수처법 개정안 발의를 환영합니다>\n어제 백혜련 의원님께서 '공수처법 개정안'을...       4.2K
# 705  <어려운 결단 하신 이용섭 광주시장님>\n광역시도 통합은 역내 균형발전, 공무원 수...       1.4K
# 706  <9/15 0시 기준 경기도 코로나19 발생 현황>  \n○ 확진자 현황 (경기도 ...        643
# 707  <조선일보 기사 수준이 왜 이럽니까?>\n명색이 전통있는 중앙일간지라는 조선일보가 ...       3.7K
# 708  <비정규직 차별 해소를 위한 작은 첫걸음>\n정규직과 비정규직간 임금 차이 극복 위...       1.5K
#
#     comment_count share_count                 date  \
# 0             113         163  2021-09-16 00:00:00
# 1             159         176  2021-09-15 00:00:00
# 2             207         187  2021-09-15 00:00:00
# 3             503         473  2021-09-15 00:00:00
# 4             127          76  2021-09-15 00:00:00
# ..            ...         ...                  ...
# 704           398         247  2020-09-15 00:00:00
# 705            65          47  2020-09-15 00:00:00
# 706            22          11  2020-09-15 00:00:00
# 707           458         201  2020-09-15 00:00:00
# 708           108         140  2020-09-15 00:00:00
#
#                                                comment      score  ratio  \
# 0    ['임금', '체불', '근절', '노동자', '의', '시름', '을', '덜어'...   5.824934   1.68
# 1    ['세계', '7', '번째', 'SLBM', '성공', '자주', '국방', '실...   5.514546   1.63
# 2    ['제', '3', '차', '경기도', '재난', '기본소득', '지급', '관련...   2.096975   0.49
# 3    ['기본소득', '의', '수혜자', '가', '전', '국민', '인', '이유'...  10.572731   2.99
# 4    ['벼랑', '끝', '에', '선', '심정', '을', '헤아려야', '합니다'... -11.242727  -3.37
# ..                                                 ...        ...    ...
# 704  ['공', '수', '처법', '개정안', '발의', '를', '환영', '합니다'...  -4.961210  -1.34
# 705  ['어려운', '결단', '하신', '이용섭', '광주', '시장님', '광역시',...   3.757273   1.28
# 706  ['915', '0시', '기준', '경기도', '코로나', '19', '발생', ...  -4.441697  -1.45
# 707  ['조선일보', '기사', '수준', '이', '왜', '이럽니까', '명색', '...  -3.800734  -1.27
# 708  ['비정규직', '차별', '해소', '를', '위', '한', '작은', '첫걸음...   3.668076   1.25
#
#        백신  부동산  ... 국민지원금    청년   문재인  윤석열  이준석   이재명    복지    접종   노조   기업
# 0     NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN  True   NaN   NaN  NaN  NaN
# 1     NaN  NaN  ...   NaN   NaN  True  NaN  NaN  True   NaN   NaN  NaN  NaN
# 2    True  NaN  ...  True   NaN  True  NaN  NaN  True  True  True  NaN  NaN
# 3     NaN  NaN  ...   NaN  True   NaN  NaN  NaN   NaN  True   NaN  NaN  NaN
# 4     NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
# ..    ...  ...  ...   ...   ...   ...  ...  ...   ...   ...   ...  ...  ...
# 704   NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
# 705   NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
# 706   NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
# 707   NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
# 708   NaN  NaN  ...   NaN   NaN   NaN  NaN  NaN   NaN   NaN   NaN  NaN  NaN
#
# [709 rows x 22 columns]

# %%
df3 = pd.read_csv('data/정세균_분석.csv')
df3 = df3.iloc[:10000,:]
df3 = df3.rename(columns={"post": "sentence"})
df3
# Out:
#                                               sentence like_count  \
# 0    존경하는 국민 여러분, \n민주당 당원동지 여러분,\n부족한 저를 오랫동안 성원해주...       2.4K
# 1    윤석열, 최재형 후보가 공수처의 윤석열 ‘고발 사주’ 수사를 불법 대선 개입으로 규...        491
# 2    지지해 주신 당원동지와 국민께 \n진심으로 감사드립니다.\n여러분의 선택을 겸허하게...        575
# 3    이재명 후보도 홍준표 후보도 품격을 지키십시오.\n차기 대통령을 선출하는 선거입니다...        394
# 4    ‘공작’은 은밀히 벌이는 일입니다. 동네방네 소문내며 벌이는 공작은 없습니다. \n...        305
# ..                                                 ...        ...
# 319  사람 사는 세상은\n함께 사는 세상입니다.\n모두 어려운 시절입니다.\n지친 마음 ...        590
# 320  기다려왔던 기쁜 소식입니다.\n국민이 함께하면 \n반드시 코로나는 극복할 수 있습니...        304
# 321  [KTV LIVE] "전국적 대유행 중대기로, 못 막으면 3단계 격상 검토" \n정...        355
# 322  생활 속 거리두기 시행 첫날입니다. \n새로운 일상에 대한 기대와 혹시 모를 위험에...        531
# 323  “어린이를 내려다보지 마시고 치어다보아(쳐다보아) 주시오”\n“어린이에게 경어를 쓰...        677
#
#      comment_count  share_count                 date  \
# 0              551          150  2021-09-13 00:00:00
# 1               35           96  2021-09-13 00:00:00
# 2               97           61  2021-09-12 00:00:00
# 3              124           54  2021-09-12 00:00:00
# 4               23           69  2021-09-12 00:00:00
# ..             ...          ...                  ...
# 319             31           28  2021-04-25 00:00:00
# 320              5            5  2021-04-24 00:00:00
# 321            175           42  2020-08-18 00:00:00
# 322             50           11  2020-05-06 00:00:00
# 323             46           12  2020-05-05 00:00:00
#
#                                                comment     score  ratio   백신  \
# 0    ['존경', '하는', '국민', '여러분', '민주당', '당원', '동지', '...  6.892790   2.42  NaN
# 1    ['윤석열', '최재형', '후보', '가', '공', '수', '처', '의', ... -7.136811  -2.07  NaN
# 2    ['지지', '해', '주신', '당', '원', '동지', '와', '국민', '...  1.000000   0.39  NaN
# 3    ['이재명', '후보', '도', '홍준표', '후보', '도', '품격', '을'... -3.536051  -1.10  NaN
# 4    ['공작', '은', '은밀', '히', '벌이는', '일', '입니다', '동',... -5.857682  -1.79  NaN
# ..                                                 ...       ...    ...  ...
# 319  ['사람', '사는', '세상', '은', '함께', '사는', '세상', '입니다...       NaN    NaN  NaN
# 320  ['기다려', '왔던', '기쁜', '소식', '입니다', '국민', '이', '함...  3.000000   1.22  NaN
# 321  ['KTV', 'LIVE', '전국', '적', '대유행', '중', '대기', '... -6.608153  -1.95  NaN
# 322  ['생활', '속', '거리', '두기', '시행', '첫날', '입니다', '새로... -0.214420  -0.07  NaN
# 323  ['어린이', '를', '내려다보지', '마시고', '치어다', '보아', '쳐다보...  7.826195   2.29  NaN
#
#      부동산  ... 국민지원금   청년   문재인   윤석열  이준석   이재명   복지   접종   노조   기업
# 0    NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 1    NaN  ...   NaN  NaN  True  True  NaN   NaN  NaN  NaN  NaN  NaN
# 2    NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 3    NaN  ...   NaN  NaN   NaN   NaN  NaN  True  NaN  NaN  NaN  NaN
# 4    NaN  ...   NaN  NaN   NaN  True  NaN   NaN  NaN  NaN  NaN  NaN
# ..   ...  ...   ...  ...   ...   ...  ...   ...  ...  ...  ...  ...
# 319  NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 320  NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 321  NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 322  NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 323  NaN  ...   NaN  NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN
#
# [324 rows x 22 columns]

# %%
df4 = pd.read_csv('data/추미애_분석.csv')
df4 = df4.iloc[:10000,:]
df4 = df4.rename(columns={"post": "sentence"})
df4
# Out:
#                                               sentence like_count  \
# 0                                            [오늘의 추미애]        798
# 1    빙의 돼부렀소 ! 어쩌야쓰까 브루다이야님 ~~~\n( 자식을 여섯이나 낳아 다 기르...       2.6K
# 2    16일(목) 추미애 후보 광주 오후일정\n■오후3시 \n빚고을시민햇빛발전소 협동조합...        770
# 3    윤석열이 검찰총장으로서 조직을 사유화해 정치에 노골적으로 개입한 윤석열의 난에 그 ...       5.6K
# 4    존경하는 국민 여러분, 광주시민과 전남도민 여러분!\n지난 7월 첫 번째 지역일정으...       3.1K
# ..                                                 ...        ...
# 396  개혁을 바라는 민주시민에 맞서 검찰과 언론이 반개혁 동맹전선을 형성하고 있습니다. ...       5.1K
# 397  문제 언론이 계속 문제성 보도를 합니다. 대단합니다. 관음증 보도에 대한 답변이 이...       4.6K
# 398  여성 장관에 대한 언론의 관음 증세가 심각합니다. 연가를 내고 산사로 간 첫날(7월...       7.4K
# 399  회전문식 엉터리 보도관행을 고발합니다.  \n장관이 공개를 목적으로 직접 작성해서 ...       3.3K
# 400  산사로 간 뜻은 제게 로비를 하지 말라는 경고였습니다. 하다하다 안되니까  말없는 ...         4K
#
#     comment_count share_count                 date  \
# 0              72          25  2021-09-16 00:00:00
# 1             160          76  2021-09-16 00:00:00
# 2              62          20  2021-09-16 00:00:00
# 3             224         821  2021-09-16 00:00:00
# 4             219         257  2021-09-16 00:00:00
# ..            ...         ...                  ...
# 396           568         332  2020-07-16 00:00:00
# 397           415         116  2020-07-16 00:00:00
# 398          1.1K         719  2020-07-14 00:00:00
# 399           353         218  2020-07-13 00:00:00
# 400           421         234  2020-07-12 00:00:00
#
#                                                comment      score  ratio   백신  \
# 0                                   ['오늘', '의', '추미애']   0.000000   0.00  NaN
# 1    ['빙의', '돼', '부렀소', '어쩌', '야', '쓰까', '브루', '다이야...  -2.000000  -0.79  NaN
# 2    ['16일', '목', '추미애', '후보', '광주', '오후', '일정', '오...  -4.957440  -1.78  NaN
# 3    ['윤석열', '이', '검찰총장', '으로서', '조직', '을', '사유화', ... -15.646644  -4.63  NaN
# 4    ['존경', '하는', '국민', '여러분', '광주', '시민', '과', '전남...  -9.872319  -2.44  NaN
# ..                                                 ...        ...    ...  ...
# 396  ['개혁', '을', '바라는', '민주', '시민', '에', '맞서', '검찰'...  -0.916511  -0.34  NaN
# 397  ['문제', '언론', '이', '계속', '문제', '성', '보도', '를', ...  -2.916511  -1.23  NaN
# 398  ['여성', '장관', '에', '대한', '언론', '의', '관음', '증세',... -31.693069  -8.01  NaN
# 399  ['회', '전문식', '엉터리', '보도', '관행', '을', '고발', '합니...  -5.000000  -1.58  NaN
# 400  ['산사', '로', '간', '뜻', '은', '제', '게', '로비', '를'...  -2.025749  -0.76  NaN
#
#      부동산  ... 재난지원금 국민지원금   청년   문재인   윤석열  이준석  이재명   복지   접종   기업
# 0    NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2    NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  ...   NaN   NaN  NaN   NaN  True  NaN  NaN  NaN  NaN  NaN
# 4    NaN  ...   NaN   NaN  NaN  True  True  NaN  NaN  NaN  NaN  NaN
# ..   ...  ...   ...   ...  ...   ...   ...  ...  ...  ...  ...  ...
# 396  NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 397  NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 398  NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 399  NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 400  NaN  ...   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
# [401 rows x 21 columns]

# %%
df5 = pd.read_csv('data/유승민_분석.csv')
df5 = df5.iloc[:10000,:]
df5 = df5.rename(columns={"post": "sentence"})
df5
# Out:
#                                               sentence like_count  \
# 0    < 유승민의 약속: 자영업자 손실보상, 강하고 현실적인 해법을 약속합니다 >  \n...        127
# 1    [희망캠프에서 알려드립니다]\n유승민 대선 예비후보는 오늘(16일) 국민의힘 대선후...        120
# 2    < 윤석열 후보님, 중문학과 장동원 학생의 질문에 답해주세요 >\n윤석열 후보님, ...        414
# 3    < 어젯밤 인스타 라방에서의 소중한 말씀들... >\n어젯밤 두번째 인스타 라방을 ...        277
# 4    [희망캠프에서 알려드립니다]\n유승민 예비후보의 9월 16일(목) 일정 안내드립니다...        149
# ..                                                 ...        ...
# 429  국군의날입니다.\n제 지역구인 대구 동구 K2 공군기지에서 열리는 국군의날 행사로 ...        686
# 430  대통령의 협박을 이겨내라.\n그게 진정한 검찰개혁이다!\n오늘 문재인 대통령은 "검...       1.4K
# 431  당신들은 북한의 보훈처냐?\n하재헌 중사는 2015년 8월 4일 북한이 DMZ 수색...       1.3K
# 432  국민을 우롱하는 대통령의 난치성 자화자찬\n문재인 대통령은 오늘 "우리 경제가 어려...       1.3K
# 433  살아있는 권력을 법대로! 그게 진짜 검찰개혁이다.\n조국 법무장관 임명 이후 "반대...       1.2K
#
#      comment_count  share_count                 date  \
# 0               17           25  2021-09-16 00:00:00
# 1               17           14  2021-09-16 00:00:00
# 2               57           35  2021-09-16 00:00:00
# 3               40           43  2021-09-16 00:00:00
# 4               32           10  2021-09-15 00:00:00
# ..             ...          ...                  ...
# 429             60           17  2019-10-01 00:00:00
# 430            830           81  2019-09-27 00:00:00
# 431            300           90  2019-09-17 00:00:00
# 432            293           79  2019-09-16 00:00:00
# 433            318           49  2019-09-15 00:00:00
#
#                                                comment      score  ratio   백신  \
# 0    ['유승민', '의', '약속', '자영', '업자', '손실보상', '강하고', ...   0.537221   0.16  NaN
# 1    ['희망', '캠프', '에서', '알려', '드립니다', '유승민', '대선', ...   3.000000   1.04  NaN
# 2    ['윤석열', '후보', '님', '중문', '학과', '장동', '원', '학생'... -20.404472  -5.46  NaN
# 3    ['어젯밤', '인스타', '라', '방', '에서의', '소중한', '말씀', '... -15.246075  -4.34  NaN
# 4    ['희망', '캠프', '에서', '알려', '드립니다', '유승민', '예비', ...   2.000000   0.75  NaN
# ..                                                 ...        ...    ...  ...
# 429  ['국군의날', '입니다', '제', '지역구', '인', '대구', '동구', '...   5.880272   1.88  NaN
# 430  ['대통령', '의', '협박', '을', '이겨내라', '그게', '진정한', '... -22.776677  -6.36  NaN
# 431  ['당신', '들', '은', '북한', '의', '보훈처', '냐', '하재', ... -12.433626  -3.59  NaN
# 432  ['국민', '을', '우롱', '하는', '대통령', '의', '난치', '성',... -15.508067  -4.48  NaN
# 433  ['살아있는', '권력', '을', '법대', '로', '그게', '진짜', '검찰... -15.045287  -4.20  NaN
#
#      부동산  ... 재난지원금    청년   문재인   윤석열   이준석  이재명    복지   접종   노조    기업
# 0    NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN  True
# 1    NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN   NaN
# 2    NaN  ...   NaN  True   NaN  True   NaN  NaN  True  NaN  NaN  True
# 3    NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN   NaN
# 4    NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN   NaN
# ..   ...  ...   ...   ...   ...   ...   ...  ...   ...  ...  ...   ...
# 429  NaN  ...   NaN   NaN   NaN   NaN  True  NaN  True  NaN  NaN   NaN
# 430  NaN  ...   NaN   NaN  True   NaN   NaN  NaN   NaN  NaN  NaN   NaN
# 431  NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN   NaN
# 432  NaN  ...   NaN   NaN  True   NaN   NaN  NaN   NaN  NaN  NaN  True
# 433  NaN  ...   NaN   NaN   NaN   NaN   NaN  NaN   NaN  NaN  NaN   NaN
#
# [434 rows x 21 columns]

# %%
df6 = pd.read_csv('data/윤석열_분석.csv')
df6 = df6.iloc[:10000,:]
df6 = df6.rename(columns={"post": "sentence"})
df6
# Out:
#                                              sentence like_count  \
# 0   북한은 지난 주말 순항미사일을 발사한데 이어 오늘 다시 탄도미사일로 추정되는 무력시...       1.8K
# 1   존경하는 국민여러분, \n그리고 당원동지 여러분\n국민의힘 대선 예비후보 윤석열입니...       4.4K
# 2   선비정신과 충절의 고장, 안동이 백신산업의 요람이자 바이오산업 도시로 떠오르고 있습...       2.4K
# 3   상상23 청년 세미나 ‘청년, 희망을 해킹하라’에 참석해 청년들의 정책을 귀담아들었...       2.8K
# 4   소상공인 여러분들! 안정적으로 사실 수 있도록\n정권교체, 경제살리기 반드시 해내겠...       1.8K
# ..                                                ...        ...
# 80                              오늘 국민 기자회견 사진도 공유합니다.       6.5K
# 81  오늘 국민 여러분께 말씀드린 \n<윤석열 국민 기자회견문> 전문을 올립니다.\n--...       6.4K
# 82  안녕하세요\n국민 여러분, 그리고 페친 여러분! \n여러분께 더 가까이 다가가고\n...       6.8K
# 83                                       No post text         5K
# 84                                             토리와 함께       7.9K
#
#    comment_count  share_count                 date  \
# 0            568           87  2021-09-15 00:00:00
# 1           1.4K          281  2021-09-15 00:00:00
# 2            630          141  2021-09-14 00:00:00
# 3            685          159  2021-09-13 00:00:00
# 4            840          143  2021-09-10 00:00:00
# ..           ...          ...                  ...
# 80           398           61  2021-06-29 00:00:00
# 81           420          107  2021-06-29 00:00:00
# 82           910           81  2021-06-29 00:00:00
# 83           176           15  2021-06-29 00:00:00
# 84          1.4K           99  2021-06-29 00:00:00
#
#                                               comment      score  ratio    백신  \
# 0   ['북한', '은', '지난', '주말', '순항미사일', '을', '발사', '한...  -1.479625  -0.48   NaN
# 1   ['존경', '하는', '국민', '여러분', '그리고', '당원', '동지', '...  -0.398125  -0.11   NaN
# 2   ['선비', '정신과', '충절', '의', '고장', '안동', '이', '백',...  -1.479625  -0.51  True
# 3   ['상상', '23', '청년', '세미나', '청년', '희망', '을', '해킹...  -4.918500  -1.73   NaN
# 4   ['소상', '공인', '여러분', '들', '안정', '적', '으로', '사실'...   1.000000   0.42   NaN
# ..                                                ...        ...    ...   ...
# 80       ['오늘', '국민', '기자회견', '사진', '도', '공유', '합니다']   0.000000   0.00   NaN
# 81  ['오늘', '국민', '여러분', '께', '말씀드린', '윤석열', '국민', ... -13.673999  -3.26   NaN
# 82  ['안녕하세요', '국민', '여러분', '그리고', '페친', '여러분', '여러...   0.252424   0.10   NaN
# 83                             ['No', 'post', 'text']  -0.731390  -0.50   NaN
# 84                                  ['토리', '와', '함께']   1.000000   0.68   NaN
#
#      부동산    북한 재난지원금    청년   문재인   윤석열  이재명   복지   접종   노조    기업
# 0    NaN  True   NaN   NaN  True   NaN  NaN  NaN  NaN  NaN   NaN
# 1   True   NaN   NaN  True  True  True  NaN  NaN  NaN  NaN   NaN
# 2    NaN   NaN   NaN  True   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 3    NaN   NaN   NaN  True   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 4    NaN   NaN   NaN   NaN   NaN  True  NaN  NaN  NaN  NaN   NaN
# ..   ...   ...   ...   ...   ...   ...  ...  ...  ...  ...   ...
# 80   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 81   NaN   NaN   NaN  True  True  True  NaN  NaN  NaN  NaN  True
# 82   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 83   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
# 84   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN
#
# [85 rows x 20 columns]

# %%
df7 = pd.read_csv('data/홍준표_분석.csv')
df7 = df7.iloc[:10000,:]
df7 = df7.rename(columns={"post": "sentence"})
df7
# Out:
#                                               sentence like_count  \
# 0    -조사개요-\n조사의뢰 : 뉴스토마토\n조사기관 : 미디어토마토\n조사일시 : 20...        776
# 1                               추석 민심이 지나면 더 기울어 질겁니다.       1.2K
# 2    jp희망 편지 23 \n자영업자.소상공인 분들의 극단적인 선택이 줄을 잇는 비극적인...        898
# 3    당에서 공명선거 추진단을 만들어 놓고\n특정후보 옹호나 하면서\n그 후보측에서 경쟁...       1.4K
# 4    서울대 사회과학대 학생회 초청으로 특강을 가서 10분 기조발제 하고 1시간 20분 ...       1.1K
# ..                                                 ...        ...
# 457  어머님 산소에 왔습니다.\n경남지사때는 매달 왔는데 서울로 올라가고 나서는 드문드문...       2.9K
# 458  요즘 유행하는 아바타 사진 입니다.\n좌측은 접니다만 우측은 누구인지 한번 맞추어 ...       1.9K
# 459  요즘은 출근하면 나랏일 보다가 쉴때는 40여년 전 대학시절에 읽었던 이병주 선생의 ...       1.4K
# 460  오늘 서욱 국방부 장관 내정자 인사 청문회에서 서욱 후보자로부터 \n한미일 자유주의...       1.4K
# 461  정치는 한때 지나가는 바람에 불과한 것인데 \n국방부가 추미애 아들 방어의 최전선에...       1.9K
#
#      comment_count  share_count                 date  \
# 0               51           48  2021-09-16 00:00:00
# 1               39           62  2021-09-16 00:00:00
# 2               35           70  2021-09-16 00:00:00
# 3               49           49  2021-09-15 00:00:00
# 4               41           53  2021-09-15 00:00:00
# ..             ...          ...                  ...
# 457             60           46  2020-09-20 00:00:00
# 458            123           41  2020-09-17 00:00:00
# 459             50           41  2020-09-17 00:00:00
# 460             63           41  2020-09-16 00:00:00
# 461             59          101  2020-09-16 00:00:00
#
#                                                comment     score  ratio   백신  \
# 0    ['조사', '개요', '조사', '의뢰', '뉴스', '토마토', '조사', '기...  2.561490   0.89  NaN
# 1     ['추석', '민심', '이', '지나면', '더', '기울어', '질', '겁니다'] -0.494680  -0.26  NaN
# 2    ['jp', '희망', '편지', '23', '자영', '업자', '소상', '공인... -6.800293  -2.18  NaN
# 3    ['당', '에서', '공명', '선거', '추진단', '을', '만들어', '놓고... -8.387470  -2.64  NaN
# 4    ['서울대', '사회과학', '대', '학생회', '초청', '으로', '특강', ...  0.424811   0.17  NaN
# ..                                                 ...       ...    ...  ...
# 457  ['어머님', '산소', '에', '왔습니다', '경남', '지', '사', '때'...  0.252424   0.10  NaN
# 458  ['요즘', '유행', '하는', '아바타', '사진', '입니다', '좌측', '...  1.000000   0.41  NaN
# 459  ['요즘', '은', '출근', '하면', '나랏일', '보다가', '쉴', '때'... -0.214619  -0.07  NaN
# 460  ['오늘', '서욱', '국방부', '장관', '내정자', '인사', '청문회', ... -6.000000  -1.89  NaN
# 461  ['정치', '는', '한때', '지나가는', '바람', '에', '불과한', '것... -1.000000  -0.35  NaN
#
#      부동산  ... 재난지원금   청년  문재인  윤석열  이준석  이재명   복지   접종   노조   기업
# 0    NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..   ...  ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 457  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 458  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 459  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 460  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 461  NaN  ...   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [462 rows x 21 columns]

# %%
df8 = pd.read_csv('data/황교안_분석.csv')
df8 = df8.iloc[:10000,:]
df8 = df8.rename(columns={"post": "sentence"})
df8
# Out:
#                                               sentence like_count  \
# 0                                         No post text         96
# 1    <故조용기 목사님을 추모합니다>\n주님의 종이 하나님의 부름을 받으셨습니다. 이 땅...        826
# 2    <‘깜놀 10억 벤처창업 배틀’로 스타트업 강국을 실현하겠습니다>\n오늘 판교 테크...        479
# 3    <‘깜놀 10억 벤처창업 배틀’로 스타트업 강국을 실현하겠습니다>\n오늘 판교밸리에...        465
# 4    <이래도 되는 겁니까?>\n서울시가 10년간 1조 가까운 시민혈세를 시민단체에게 비...       1.1K
# ..                                                 ...        ...
# 205  백의종군 첫 행선지로 부산을 찾았습니다. \n'국민 속으로'는 제가 <민생대장정> ...        985
# 206  ‘야만의 정치’를 끝내야 합니다.\n ‘개와 늑대의 시간’은 지났습니다. 우리는 그...       1.5K
# 207  ‘적반하장’도 유분수다. \n여권의 '정치검사 윤석열' 운운은 정말 뻔뻔한 주장이다...       1.6K
# 208  도무지 끝날 것 같지 않던 겨울이 어김없이 물러나고 있습니다. 드디어 매화향이 그윽...       1.5K
# 209  "문재인정권, 나라를 어디까지 망가뜨리려는가?"\n- 공수처법 일방처리는 대한민국 ...       2.7K
#
#      comment_count  share_count                 date  \
# 0                9            7  2021-08-02 00:00:00
# 1               70           22  2021-09-15 00:00:00
# 2               55           25  2021-09-14 00:00:00
# 3               72           31  2021-09-14 00:00:00
# 4              112           79  2021-09-14 00:00:00
# ..             ...          ...                  ...
# 205            339           67  2021-03-11 00:00:00
# 206            363          107  2021-03-10 00:00:00
# 207            346           94  2021-03-07 00:00:00
# 208            223          106  2021-03-04 00:00:00
# 209            976          354  2020-12-10 00:00:00
#
#                                                comment     score  ratio   백신  \
# 0                               ['No', 'post', 'text'] -0.731390  -0.50  NaN
# 1    ['조용기', '목사', '님', '을', '추모', '합니다', '주님', '의'...  0.321631   0.11  NaN
# 2    ['깜놀', '10억', '벤', '처', '창업', '배틀', '로', '스타트업...  0.750472   0.22  NaN
# 3    ['깜놀', '10억', '벤', '처', '창업', '배틀', '로', '스타트업...  0.750472   0.22  NaN
# 4    ['이래도', '되는', '겁', '니까', '서울시', '가', '10년', '간... -4.142318  -1.23  NaN
# ..                                                 ...       ...    ...  ...
# 205  ['백의종군', '첫', '행선', '지로', '부산', '을', '찾았습니다', ... -1.000000  -0.33  NaN
# 206  ['야만', '의', '정치', '를', '끝내야', '합니다', '개', '와',... -2.242135  -0.61  NaN
# 207  ['적반하장', '도', '유분수', '다', '여권', '의', '정치검사', '... -1.606267  -0.47  NaN
# 208  ['도무지', '끝날', '것', '같지', '않던', '겨울', '이', '어김없... -8.526771  -2.25  NaN
# 209  ['문재인', '정권', '나라', '를', '어디', '까지', '망', '가',... -7.606267  -2.11  NaN
#
#       부동산  ... 재난지원금    청년   문재인   윤석열  이준석  이재명   복지   접종   노조    기업
# 0     NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1     NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 2     NaN  ...   NaN  True   NaN   NaN  NaN  NaN  NaN  NaN  NaN  True
# 3     NaN  ...   NaN  True   NaN   NaN  NaN  NaN  NaN  NaN  NaN  True
# 4     NaN  ...   NaN   NaN  True   NaN  NaN  NaN  NaN  NaN  NaN  True
# ..    ...  ...   ...   ...   ...   ...  ...  ...  ...  ...  ...   ...
# 205   NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 206  True  ...   NaN   NaN  True   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 207   NaN  ...   NaN   NaN  True  True  NaN  NaN  NaN  NaN  NaN   NaN
# 208   NaN  ...   NaN   NaN  True   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 209   NaN  ...   NaN   NaN  True   NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [210 rows x 21 columns]

# %%
data=[df1,df2,df3,df4,df5,df6,df7,df8]
blue=[df1,df2,df3,df4]  #여당
red=[df5,df6,df7,df8]   #야당

# %%
word_list=['백신','부동산','북한','재난지원금','국민지원금','청년','문재인','윤석열','이준석','이재명','복지','접종','노조','기업']
for word in word_list:
    for df in data:
        for i in range(len(df)):
            tmp=df.loc[i,'sentence']
            flag=False
            if word in tmp:
                flag=True
            if flag:
                df.loc[i,str(word)]=True

# %%
word="백신"
plt.style.use('default')
plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.boxplot([df1[df1[word]==True]['ratio'].dropna(),
             df2[df2[word]==True]['ratio'].dropna(),
             df3[df3[word]==True]['ratio'].dropna(),
             df4[df4[word]==True]['ratio'].dropna(),
             df5[df5[word]==True]['ratio'].dropna(),
             df6[df6[word]==True]['ratio'].dropna(),
             df7[df7[word]==True]['ratio'].dropna(),
             df8[df8[word]==True]['ratio'].dropna()
             ]);
plt.title(word)
# Out:
# Text(0.5, 1.0, '백신')

# %%
for df in blue:
    plt.scatter(df[df['접종']==True]['date'],df[df['접종']==True]['score'], color='blue')
for df in red:
    plt.scatter(df[df['접종']==True]['date'],df[df['접종']==True]['score'], color='red')

# %%
df1
# Out:
#                                               sentence like_count  \
# 0    <홍영표 김종민 신동근 의원님 지지선언, 힘이 솟습니다>\n더불어민주당 홍영표, 김...        636
# 1    <윤석열씨의 대책없는 노동관>\n“손발로 하는 노동은 인도도 안 하고 아프리카나 한...        633
# 2    <광주시민께 드리는 글 - 민주당이 승리하도록,  결선투표를 만들어주십시오>\n존경...       1.3K
# 3    <정치인의 망발을 언제까지 견뎌야 합니까>\n어제 국회 본회의 대정부질문에서 국민의...       1.7K
# 4    <역사의 순간, 역사적인 선택에 참여해주십시오>\n더불어민주당의 대선후보를 선출하는...       1.1K
# ..                                                 ...        ...
# 609  8월 7~8일 큰 수해를 당한 전북 남원, 전남 곡성 구례, 경남 하동 화개장터. ...         2K
# 610  서울 종로구 통인시장. 국내외 관광객과 손님들로 붐비던 곳. 코로나19로 한산해졌습...       2.8K
# 611  저희 더불어민주당 소속 오영환 국회의원의 미담이 한 달 만에 세상에 알려졌습니다.\...       3.7K
# 612  국내 제약기업 셀트리온이 코로나19 항체치료제 9만명분 생산체제를 갖춘다고 합니다....       2.2K
# 613  코로나19로 많은 국민께서 고통 받고 계십니다. 어제 14일 중소기업중앙회(회장 김...       1.7K
#
#     comment_count  share_count                 date  \
# 0             224          224  2021-09-16 00:00:00
# 1             413          264  2021-09-16 00:00:00
# 2             817          450  2021-09-16 00:00:00
# 3             534          482  2021-09-15 00:00:00
# 4             408          330  2021-09-14 00:00:00
# ..            ...          ...                  ...
# 609           145          132  2020-09-19 00:00:00
# 610           210          116  2020-09-18 00:00:00
# 611           177          163  2020-09-17 00:00:00
# 612           188          114  2020-09-17 00:00:00
# 613           265          124  2020-09-15 00:00:00
#
#                                                comment         score  ratio  \
# 0    ['홍영표', '김종민', '신동근', '의원님', '지지', '선언', '힘', ...  1.000000e+01   3.00
# 1    ['윤석열', '씨', '의', '대책', '없는', '노동', '관', '손발',...  8.000000e+00   2.29
# 2    ['광주', '시민', '께', '드리는', '글', '민주당', '이', '승리'...  7.666667e+00   1.94
# 3    ['정치인', '의', '망발', '을', '언제', '까지', '견뎌야', '합'... -1.110223e-16  -0.00
# 4    ['역사', '의', '순간', '역사', '적', '인', '선택', '에', '...  5.000000e+00   1.47
# ..                                                 ...           ...    ...
# 609  ['8월', '78일', '큰', '수해', '를', '당한', '전북', '남원'... -4.943358e+00  -1.88
# 610  ['서울', '종로구', '통인시장', '국내외', '관광객', '과', '손님',...  5.048487e-01   0.21
# 611  ['저희', '더불어', '민주당', '소속', '오영환', '국회의원', '의',...  1.091078e+00   0.41
# 612  ['국내', '제약기업', '셀트리온', '이', '코로나', '19', '항체',... -3.330669e-16  -0.00
# 613  ['코로나', '19', '로', '많은', '국민', '께서', '고통', '받고... -3.723308e+00  -1.42
#
#       백신  부동산  ... 국민지원금    청년   문재인   윤석열  이준석  이재명    복지   접종   노조    기업
# 0    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN  True  NaN  NaN   NaN
# 1    NaN  NaN  ...   NaN  True   NaN  True  NaN  NaN   NaN  NaN  NaN   NaN
# 2    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN  True  NaN  NaN   NaN
# 3    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 4    NaN  NaN  ...   NaN   NaN  True   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# ..   ...  ...  ...   ...   ...   ...   ...  ...  ...   ...  ...  ...   ...
# 609  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 610  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 611  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# 612  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  True
# 613  NaN  NaN  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN  NaN  NaN  True
#
# [614 rows x 22 columns]

# %%
df1[df1['접종']==True]['score']
# Out:
# 52    -1.300000e+01
# 65    -3.333333e-01
# 73     0.000000e+00
# 77     3.000000e+00
# 80    -3.881285e+00
# 99     4.000000e+00
# 154    0.000000e+00
# 250   -3.000000e+00
# 271    7.000000e+00
# 324   -3.330669e-16
# 325   -2.000000e+00
# 370    1.389975e+00
# 393    1.000000e+00
# 416   -1.553383e+00
# 431    7.706809e-02
# 439    3.610025e+00
# 448    8.359635e+00
# 454    3.000000e+00
# 462   -5.000000e+00
# 483    3.386134e+00
# 487   -3.000000e+00
# 512   -4.491310e+00
# 529    2.276692e+00
# 541   -4.000000e+00
# 604   -4.389975e+00
# Name: score, dtype: float64

# %%
cnt=[]
score=[]
keyword='백신'
for df in data:
    cnt.append(df[df[keyword]==True]['score'].count())
    score.append(df[df[keyword]==True]['score'].mean())
plt.scatter(cnt[0:4],score[0:4], color='blue')
plt.scatter(cnt[4:],score[4:], color='red')

# %%
cnt=[]
score=[]
keyword='문재인'
for df in data:
    cnt.append(df[df[keyword]==True]['score'].count())
    score.append(df[df[keyword]==True]['score'].mean())
plt.scatter(cnt[0:4],score[0:4], color='blue')
plt.scatter(cnt[4:],score[4:], color='red')

# %%
score
# Out:
# [3.1556023052603432,
#  2.990350293960505,
#  0.7504810445044222,
#  -4.601350229842371,
#  -12.096827688663199,
#  -6.432924451717358,
#  -2.3803977878653773,
#  -2.2632278881264805]
